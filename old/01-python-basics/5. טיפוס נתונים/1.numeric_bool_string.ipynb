# %% [markdown]
# ________________
# # Numeric types:

# %%
x=32222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222423
print(type(x))
print(x+x)
# Out:
# <class 'int'>
# 64444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444444846

# %%
x=2.0
print(type(x))
# Out:
# <class 'float'>

# %%
x=2j
print(type(x))
x**2
# Out:
# <class 'complex'>
# (-4+0j)

# %% [markdown]
# # Boolean:

# %%
print(type(True))
print(type(2 > 3))

# %%
print(bool("Hello"))
print(bool(15))
print(bool(0))
print(bool(0.0))

# %% [markdown]
# # Strings:

# %%
print(type('String'))

# %% [markdown]
# ### string operators:

# %%
# string operators:
# Concatenation:
print('Hellow'+'World')
print('Hellow'+ ' ' + 'World') 
# Self Concatenation:
print('a' * 4)

# %%
# Slicing strings:
my_str = 'This is my string'
print(my_str[5:7])
print(my_str[8:])
print(my_str[:7])
print(my_str[-9:-1])
print(my_str[0:15:2])

# %%
# modifying strings: 
print('upper & lower functions:')
print(my_str.upper())
print(my_str.lower())

# %%
#The strip() method removes any whitespace from the beginning or the end:
print('\nstrip function: ')
my_str = ' '+my_str+' '
print(my_str)
my_str = my_str.strip()
print(my_str)

# %%
#The replace() method replaces a string with another string:
print('\nreplace function:')
print(my_str.replace(' is ', " is 'not' "))

# %% [markdown]
# [More about string methods you can find here](https://www.w3schools.com/python/python_ref_string.asp)

# %% [markdown]
# ### String formatting:

# %%
# String formating: 
first_name = "Eric"
last_name = "Idle"
age = 74
profession = "comedian"
affiliation = "Monty Python"

print('\nfstring: ')
print(f"Hello, {first_name} {last_name}. You are {age+1}. You are a {profession}. You were a member of {affiliation}.")

print('format function: ')
template="Hello, {first_name} {last_name}. You are {age}. You are a {profession}. You were a member of {affiliation}."
print(template.format(first_name=first_name, last_name=last_name, age=age+1, profession=profession, affiliation=affiliation))

# %%
#fstring: 
val = 12.3
print(f'{val:.2f}')
print(f'{val:.5f}')

# %%
a = 300
# hexadecimal
print(f"{a:x}")
# octal
print(f"{a:o}")
# scientific
print(f"{a:e}")
